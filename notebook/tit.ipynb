# %%
import pandas as pd
import numpy as np

# %%
total_people=pd.read_csv("gender_submission.csv")
total_people.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
total_people.shape
# Out:
# (418, 2)

# %%
test=pd.read_csv("test.csv")
print(test.head())
test.shape
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S
# (418, 11)

# %%
train=pd.read_csv("train.csv")
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.shape
# Out:
# (891, 12)

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train = train.drop(['PassengerId', 'Pclass','Name',  
                    'SibSp', 'Parch', 'Ticket', 'Fare', 
                    'Cabin', 'Embarked'], axis=1)

# %%
train.shape
# Out:
# (891, 3)

# %%
test=test.drop(['PassengerId', 'Pclass','Name',  
                    'SibSp', 'Parch', 'Ticket', 'Fare', 
                    'Cabin', 'Embarked'], axis=1)

# %%
test.shape
# Out:
# (418, 2)

# %%
train.head()
# Out:
#    Survived     Sex   Age
# 0         0    male  22.0
# 1         1  female  38.0
# 2         1  female  26.0
# 3         1  female  35.0
# 4         0    male  35.0

# %%
train['Sex'] = train['Sex'].replace({'male': 1, 'female': 0})
# Out:
# /var/folders/7q/j3s102ss7vl83m5y390b5gph0000gn/T/ipykernel_34086/955660753.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train['Sex'] = train['Sex'].replace({'male': 1, 'female': 0})

# %%
train.head()
# Out:
#    Survived  Sex   Age
# 0         0    1  22.0
# 1         1    0  38.0
# 2         1    0  26.0
# 3         1    0  35.0
# 4         0    1  35.0

# %%
train.isnull().sum()
# Out:
# Survived      0
# Sex           0
# Age         177
# dtype: int64

# %%
print(train['Age'].mean())
# Out:
# 29.69911764705882

# %%
train['Age'] = train['Age'].fillna(train['Age'].mean())

# %%
train.isnull().sum()
# Out:
# Survived    0
# Sex         0
# Age         0
# dtype: int64

# %%
test.head()
# Out:
#       Sex   Age
# 0    male  34.5
# 1  female  47.0
# 2    male  62.0
# 3    male  27.0
# 4  female  22.0

# %%
test['Sex'] = test['Sex'].replace({'male': 1, 'female': 0})
# Out:
# /var/folders/7q/j3s102ss7vl83m5y390b5gph0000gn/T/ipykernel_34086/1971732509.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test['Sex'] = test['Sex'].replace({'male': 1, 'female': 0})

# %%
test.isnull().sum()
# Out:
# Sex     0
# Age    86
# dtype: int64

# %%
test['Age'] = test['Age'].fillna(test['Age'].mean())

# %%
test.isnull().sum()
# Out:
# Sex    0
# Age    0
# dtype: int64

# %%
X = train.drop('Survived', axis=1)
y = train['Survived']

# %%
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42)

# %%
model = SVC()
model.fit(X, y)
# Out:
# SVC()

# %%
y_pred = model.predict(X_test)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.4134078212290503

# %%
model2=DecisionTreeClassifier()
model2.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2=model2.predict(X_test)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
accuracy = accuracy_score(y_test, y_pred2)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.4134078212290503

# %%
model3=RandomForestClassifier()
model3.fit(X,y)
# Out:
# RandomForestClassifier()

# %%
y_pred3=model3.predict(X_test)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
accuracy = accuracy_score(y_test, y_pred3)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.4134078212290503

# %%
from sklearn.linear_model import SGDClassifier
clf = SGDClassifier(loss="hinge", penalty="l2", max_iter=5)
clf.fit(X, y)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_stochastic_gradient.py:738: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# SGDClassifier(max_iter=5)

# %%
g_pred=clf.predict(X_test)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SGDClassifier was fitted with feature names
#   warnings.warn(

# %%
accuracy = accuracy_score(y_test, g_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7821229050279329

# %%
# %pip install xgboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 547.9 kB/s eta 0:00:00a 0:00:01
# ...

# %%
import xgboost as xgb
from xgboost import XGBClassifier

# %%
params = {
    'objective':'binary:logistic',
    'max_depth':4,
    'learning_rate':0.1,
    'n_estimators':100,
    'alpha':10
}

model_xg = XGBClassifier(**params)

model_xg.fit(X_train, y_train)

y_pred_xg = model_xg.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred_xg)
print("Model Accuracy:", accuracy)
# Out:
# Model Accuracy: 0.7821229050279329

# %%
import pandas as pd

new_passenger = pd.DataFrame({
    
    'Sex': [1],     # must match encoding (e.g., male=1, female=0)
    'Age': [22]
    
})

# %%
prediction = model_xg.predict(new_passenger)
print(prediction)
